# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeHunterOfficial/ABC_DataMining/blob/main/Python/Python-2025/%D0%9F%D0%9E%D0%9B%D0%9D%D0%AB%D0%99_%D0%9A%D0%A3%D0%A0%D0%A1_%D0%9F%D0%9E_%D0%9E%D0%A1%D0%9D%D0%9E%D0%92%D0%90%D0%9C_%D0%9F%D0%A0%D0%9E%D0%93%D0%A0%D0%90%D0%9C%D0%9C%D0%98%D0%A0%D0%9E%D0%92%D0%90%D0%9D%D0%98%D0%AF_%D0%9D%D0%90_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐍 **ПОЛНЫЙ КУРС ПО ОСНОВАМ ПРОГРАММИРОВАНИЯ НА PYTHON**
# *От “Hello, World!” — до работы с файлами, папками, SQLite и замыканиями. Без ООП. Готов к преподаванию “из коробки”.*
#
#
#
# ## 🎯 **Модуль 0: Введение в программирование и настройка среды**
#
# - Что такое программирование? Зачем это нужно в 2025+.
# - Почему Python? Простота, мощь, универсальность.
# - Установка Python 3.11+ (официальный сайт, pyenv, asdf).
# - Выбор и настройка среды: VSCode (с расширениями), PyCharm Community, Thonny.
# - Запуск кода: REPL, скрипты (.py), Jupyter (ознакомительно).
# - Виртуальные окружения (venv): зачем, как создать, активировать, деактивировать.
# - Работа с терминалом: cd, ls/dir, mkdir, rm/del, python script.py.
#
#
# ### 🔁 **Модуль 0.5: Система контроля версий Git, GitHub и основы CI/CD**
#
# #### **Часть 1: Основы Git (Локальная работа)**
# - **Зачем нужен Git?**
#   - История изменений, откат ошибок, командная работа.
#   - **Git — это не просто backup. Это история мышления разработчика** — почему, когда и как менялся код.
# - **Установка и базовая настройка Git:**
#   - Установка (официальный сайт, пакетные менеджеры).
#   - Первоначальная настройка: `git config --global user.name`, `git config --global user.email`.
# - **Основы работы с репозиторием:**
#   - Инициализация: `git init`.
#   - **`README.md` — первый файл в репозитории.** Опишите, что делает проект, как его запустить. Это ваша визитка.
#   - Проверка статуса: `git status`.
#   - Добавление файлов в индекс (staging area): `git add <file>`, `git add .`.
#   - Фиксация изменений (коммит): `git commit -m "сообщение"`.
#   - Просмотр истории: `git log` (с флагами `--oneline`, `--graph`, `--all`).
# - **Ключевые понятия и практики:**
#   - Что такое `.gitignore` — зачем нужен и как составлять (шаблоны для Python).
#
# #### **Часть 2: Ветвление и работа с историей**
# - **Ветвление (Branching) — основа основ:**
#   - Создание и переключение на ветку: `git checkout -b <branch-name>` или `git switch -c <branch-name>`.
#   - Просмотр списка веток: `git branch`.
#   - Слияние веток: `git merge <branch-name>`.
# - **Работа с историей и изменениями:**
#   - **Сравнение изменений (`git diff`):**
#     - `git diff` — рабочая директория vs индекс.
#     - `git diff --staged` — индекс vs последний коммит.
#     - `git diff HEAD` — рабочая директория vs последний коммит.
#   - **Отмена изменений:**
#     *   Отмена в рабочей директории: `git restore <file>` (modern), `git checkout -- <file>` (classic).
#     *   Отмена индексации (вынос из staged): `git restore --staged <file>`.
#   - **Временное сохранение изменений (git stash):**
#     *   `git stash` или `git stash push -m "message"` — временно спрятать изменения.
#     *   `git stash list` — посмотреть список stash.
#     *   `git stash pop` — вернуть последние спрятанные изменения и удалить их из stash.
#   - **Интерактивное перебазирование (Interactive Rebase) и Сжатие коммитов (Squash):**
#     *   **Зачем?** Для очистки истории перед тем, как отправить её на GitHub.
#     *   `git rebase -i HEAD~3` (перебазировать последние 3 коммита).
#     *   В открывшемся редакторе заменить `pick` на `squash` (или `s`) у тех коммитов, которые нужно объединить.
#   - **Перебазирование (Rebase) как альтернатива слиянию (Merge):**
#     *   `git checkout feature-branch`
#     *   `git rebase main` — "перемотать" изменения feature-branch на верхушку актуальной ветки `main`.
#   - **Перенос отдельного коммита (Cherry-Pick):**
#     *   `git cherry-pick <commit-hash>` — применить изменение из одного коммита в другой ветке.
# - **Конфликты и их разрешение:**
#   *   Как выглядят и как разрешаются конфликты при `merge`, `rebase`, `cherry-pick`.
#
# #### **Часть 3: Командная работа с GitHub и Code Review**
# - **Работа с удалённым репозиторием (GitHub):**
#   - Создание репозитория на GitHub.
#   - Привязка локального репозитория к удалённому: `git remote add origin <url>`.
#   - Отправка изменений на GitHub: `git push -u origin main`.
#   - Клонирование существующего репозитория: `git clone <url>`.
#   - Получение изменений с GitHub: `git pull` ( = `git fetch` + `git merge`).
# - **Модель ветвления и Pull Request (Merge Request):**
#   - **Зачем?** Основной инструмент код-ревью и интеграции изменений в команде.
#   - **Типовая workflow:**
#     1.  `git checkout -b feature/new-auth` (создать ветку для новой функциональности).
#     2.  Вести разработку, делать коммиты.
#     3.  `git push origin feature/new-auth` (отправить ветку на GitHub).
#     4.  На GitHub создать **Pull Request (PR)** из `feature/new-auth` в `main`.
#   - **Процесс код-ревью:**
#     - Обсуждение кода в PR.
#     - Внесение правок (просто сделайте коммит и push в эту же ветку — PR обновится автоматически).
#     - Добавление ревьюверов, присвоение лейблов.
#   - **Слияние через PR:** Squash and merge, Create a merge commit, Rebase and merge.
# - **Issues, Projects, Wiki:** Использование Issues для постановки задач, Projects для организации работы (канбан-доска).
#
# - **Protected Branches и Status Checks — введение в production-культуру**
#   - **Protected Branches** — настройка в GitHub: запрет на прямой push, обязательное прохождение проверок, обязательный апрув ревьювера.
#   - **Status Checks** — автоматические проверки (например, тесты из GitHub Actions), которые должны пройти **до** того, как PR можно слить.
#   - **Зачем это нужно?** Чтобы в основную ветку попадал только **проверенный, рабочий, протестированный код** — как в профессиональных командах.
#   - **Практика для студентов:** В своём репозитории попробуйте включить защиту ветки `main` → убедитесь, что теперь нельзя пушить напрямую → сливайте изменения **только через PR**.
#
#
# #### **Часть 4: Автоматизация с GitHub Actions (CI/CD)**
# - **Что такое CI/CD (Continuous Integration / Continuous Deployment)?** Автоматизация тестирования и развертывания.
# - **Введение в GitHub Actions:**
#   - **Зачем?** Запускать автоматические тесты на каждый PR и пуш в репозиторий.
#   - **Основные понятия:**
#     - **Workflow** (Файл автоматизации) `.github/workflows/python-app.yml`.
#     - **Job** (Задача): например, "test".
#     - **Step** (Шаг): например, "установить Python", "запустить pytest".
#   - **Просмотр результатов:** Вкладка "Actions" в репозитории GitHub.
#
# #### **Практическая работа для студентов:**
#   0.  **`git clone https://github.com/username/course-template.git`** — клонируйте шаблон проекта с уже подготовленными `.gitignore`, `README.md` и структурой папок для курса.
#   1.  Перейти в папку проекта: `cd course-template`.
#   2.  Связать ваш форк с оригиналом (если нужно): `git remote add upstream <url-original-repo>`.
#   3.  Реализовать проект по следующему workflow:
#       - `git checkout -b module-5-project`
#       - Вести разработку, делая коммиты. Используйте `git diff` для проверки изменений.
#       - `git push origin module-5-project`
#       - **Создать Pull Request из `module-5-project` в `main`.**
#       - **Написать описание PR, что было сделано (можно ссылаться на Issues).**
#       - **Слить PR через кнопку на GitHub.**
#   4.  (Опционально, для продвинутых) Добавить в репозиторий простой тест и файл `requirements.txt`. Создать базовый GitHub Actions workflow для его автоматического запуска.
#
#
# ## 💬 **Модуль 1: Первые шаги — ввод, вывод, переменные, типы данных**
#
# - Функция `print()` — вывод текста, переменных, форматирование.
# - Форматирование: f-строки (основной), `.format()`, `%` (для совместимости).
# - Функция `input()` — ввод от пользователя, преобразование типов.
# - Переменные: объявление, динамическая типизация, именование (snake_case).
# - Базовые типы: `int`, `float`, `str`, `bool`, `None`.
# - Функция `type()` — определение типа.
# - Явное преобразование: `int()`, `str()`, `float()`, `bool()`.
# - Неявное преобразование — когда и как происходит.
# - Ошибки преобразования — как ловить и избегать.
#
#
#
# ## 🧮 **Модуль 2: Операторы, выражения, приоритеты**
#
# - Арифметические: `+`, `-`, `*`, `/`, `//`, `%`, `**`.
# - Сравнения: `==`, `!=`, `>`, `<`, `>=`, `<=`.
# - Логические: `and`, `or`, `not`.
# - Присваивания: `=`, `+=`, `-=`, `*=`, `/=`.
# - Приоритет операторов — таблица, скобки для управления.
# - Выражения vs инструкции.
# - Отладка через `print()` — промежуточные значения.
#
#
#
# ## 🧭 **Модуль 3: Условия — if, elif, else, тернарный оператор**
#
# - Простое ветвление: `if`
# - Двойное: `if ... else`
# - Множественное: `if ... elif ... else`
# - Вложенные условия.
# - Составные условия: `and`, `or`, `not`.
# - Тернарный оператор: `x if condition else y`
# - Практика: калькулятор, чётность, возраст, валидация, игра “угадай число” (версия 1).
#
#
#
# ## 🔁 **Модуль 4: Циклы — for, while, break, continue, else**
#
# - Цикл `while`: условие, бесконечные циклы, управление.
# - `break`, `continue`, `else` в цикле.
# - Цикл `for`: итерация по строкам, спискам, диапазонам.
# - `range()`: все формы — stop, start-stop, start-stop-step.
# - Вложенные циклы: таблицы, фигуры, матрицы.
# - Практика: поиск, сумма, факториал, простые числа, игра “угадай число” (финал).
#
#
#
# ## 📦 **Модуль 5: Функции — основы (def, параметры, return, области видимости)**
#
# - Что такое функция? Цели: переиспользование, структурирование.
# - Объявление: `def имя(параметры):`
# - Вызов, аргументы, параметры по умолчанию.
# - `return` — возврат значения, нескольких значений (кортеж), `None`.
# - Локальные и глобальные переменные — LEGB (Local, Enclosing, Global, Built-in).
# - `global` — изменение глобальных переменных (осторожно!).
# - Docstrings — документирование функций.
# - Вложенные функции — доступ к внешним переменным.
#
#
#
# ## 🌀 **Модуль 5.5: Функции как объекты — лямбда, замыкания, функции высшего порядка**
#
# - Функции — объекты первого класса: присваивание, передача, возврат, хранение.
# - Функции высшего порядка: `map`, `filter`, `sorted(key=...)`.
# - Лямбда-функции: `lambda x: x*2` — синтаксис, ограничения, применение.
# - Замыкания: захват переменных внешней функции, фабрики функций, сохранение состояния.
# - Практика: счётчики, генераторы операций, сортировка сложных объектов, фильтрация.
#
#
#
# ## 📊 **Модуль 6: Списки (list) — основы коллекций**
#
# - Создание: `[]`, `list()`.
# - Индексация, срезы, копирование.
# - Методы: `append`, `insert`, `extend`, `remove`, `pop`, `clear`, `index`, `count`, `sort`, `reverse`, `copy`.
# - Операторы: `+`, `*`, `in`.
# - Итерация: `for item in list`.
# - Вложенные списки — матрицы.
# - Практика: фильтрация, поиск, сортировка, обработка данных.
#
#
#
# ## 🧩 **Модуль 7: Кортежи, множества, словари**
#
# - **Кортежи (tuple)**: неизменяемые, распаковка, применение.
# - **Множества (set)**: уникальные элементы, операции (`|`, `&`, `-`, `^`), методы.
# - **Словари (dict)**: ключ-значение, методы (`keys`, `values`, `items`, `get`, `update`, `pop`, `setdefault`), итерация, вложенные словари.
# - Практика: подсчёт частот, группировка, конфиги, телефонная книга.
#
#
#
# ## 🔤 **Модуль 8: Строки — полный разбор**
#
# - Создание, экранирование, конкатенация, повторение.
# - Индексация, срезы.
# - Методы: `upper/lower/title/capitalize`, `strip/lstrip/rstrip`, `split/join`, `replace/find/index/count`, `startswith/endswith`, `is...()`.
# - Форматирование: f-строки, `.format()`, `%`.
# - Практика: парсинг, валидация, шифрование, статистика текста.
#
#
#
# ## 📁 **Модуль 9: Файловая система — работа с файлами и папками**
#
# > **Полностью обновлён — включает всё: от TXT до архивов, от mkdir до shutil**
#
# ### 🗂️ Часть 1: Основы файлов и папок
# - Модуль `os`: `os.listdir()`, `os.mkdir()`, `os.rmdir()`, `os.remove()`, `os.path.exists()`, `os.path.join()`, `os.getcwd()`, `os.chdir()`.
# - Модуль `pathlib` (Path): современный подход — `Path('folder/file.txt')`, `.read_text()`, `.write_text()`, `.iterdir()`, `.mkdir()`, `.unlink()`.
# - Рекурсивный обход папок: `os.walk()` — чтение всех файлов в подпапках.
# - Проверка: файл или папка? `os.path.isfile()`, `os.path.isdir()`.
# - Копирование и перемещение: модуль `shutil` — `shutil.copy()`, `shutil.move()`, `shutil.rmtree()` (осторожно!).
#
# ### 📄 Часть 2: Текстовые файлы (.txt)
# - Чтение/запись: `open('file.txt', 'r', encoding='utf-8')`.
# - Работа со строками, удаление `\n`, подсчёт строк/слов.
#
# ### 🧩 Часть 3: CSV
# - Ручной парсинг: `split(',')`.
# - Модуль `csv`: `reader`, `writer`, `DictReader`, `DictWriter`.
#
# ### 🧠 Часть 4: JSON
# - Модуль `json`: `load`, `loads`, `dump`, `dumps`, обработка ошибок.
#
# ### ⚙️ Часть 5: Конфиги (INI)
# - Модуль `configparser`: чтение секций, параметров, запись.
#
# ### 🖥️ Часть 6: Двоичные файлы
# - Режим `'rb'`, `'wb'`.
# - Модуль `pickle`: `dump`, `load` — сериализация объектов Python.
#
# ### 📜 Часть 7: Логи
# - Ручное логирование: запись с меткой времени.
# - Модуль `logging` — базовая настройка: `basicConfig`, `info`, `error`.
#
# ### 🗜️ Часть 8: Архивы
# - Модуль `zipfile`: `ZipFile`, `namelist`, `extractall`, `write`.
# - Модуль `tarfile` — ознакомительно.
#
# ### 🚨 Часть 9: Обработка ошибок
# - `FileNotFoundError`, `PermissionError`, `IsADirectoryError`, `UnicodeDecodeError`, `JSONDecodeError`.
# - Безопасное чтение/запись с `try/except`.
#
#
# ## 🗃️ **Модуль 9.5: Работа с базами данных — SQLite (без ООП)**
#
# > **Добавлен как отдельный модуль — критически важный навык даже для начинающих**
#
# - Что такое база данных? Зачем она нужна (vs файлы).
# - Что такое SQLite? Встраиваемая, файловая, не требует сервера.
# - **Модуль `sqlite3` — стандартная библиотека Python.**
# - Подключение к БД: `sqlite3.connect('mydb.sqlite')`.
# - Создание курсора: `cursor = conn.cursor()`.
# - Выполнение SQL-запросов: `cursor.execute("CREATE TABLE ...")`.
# - Основные команды SQL (в объёме курса):
#   - `CREATE TABLE users (id INTEGER, name TEXT)`
#   - `INSERT INTO users VALUES (1, 'Alice')`
#   - `SELECT * FROM users`
#   - `UPDATE users SET name='Bob' WHERE id=1`
#   - `DELETE FROM users WHERE id=1`
# - Получение данных: `cursor.fetchall()`, `cursor.fetchone()`.
# - Фиксация изменений: `conn.commit()`.
# - Закрытие: `conn.close()`.
# - Параметризованные запросы: `cursor.execute("SELECT * FROM users WHERE id=?", (user_id,))` — защита от SQL-инъекций.
# - Практические задачи:
#   - Создание таблицы “Пользователи” или “Задачи”.
#   - Добавление, чтение, обновление, удаление записей.
#   - Поиск по условию.
#   - Импорт данных из CSV в SQLite.
#   - Экспорт данных из SQLite в JSON.
#
#
#
# ## 🚨 **Модуль 10: Обработка ошибок и исключений**
#
# - Что такое исключение? Почему программы падают.
# - `try ... except ... else ... finally`.
# - Типы: `ValueError`, `TypeError`, `IndexError`, `KeyError`, `FileNotFoundError`, `ZeroDivisionError`, `sqlite3.Error`, `json.JSONDecodeError`.
# - `raise` — генерация исключений.
# - Создание своих исключений (введение).
# - Практика: защита ввода, обработка файлов, безопасные вычисления, транзакции в SQLite.
#
#
# ## 🔄 **Модуль 11: Алгоритмическое мышление и решение задач**
#
# - Что такое алгоритм? Свойства.
# - Псевдокод, блок-схемы.
# - Отладка: print, отладчик IDE.
# - Шаблоны: макс/мин, сумма, фильтр, поиск, сортировка (пузырёк — идея), рекурсия (факториал, Фибоначчи — введение).
# - Практика: калькулятор, викторина, анализатор текста, телефонная книга, дневник расходов.
#
#
#
# ## 🧠 **Модуль 12: Стиль кода, читаемость, лучшие практики**
#
# - PEP 8: отступы, имена, длина строк.
# - Комментарии: зачем и как.
# - Читаемость: функции, имена, DRY, KISS.
# - Инструменты: `black`, `ruff`, `pylint`.
# - Рефакторинг: улучшение “грязного” кода.
#
#
# ## 🎓 **Модуль 13: Проекты для закрепления**
#
# - **Проект 1: Консольный калькулятор** — с меню, историей, обработкой ошибок → **создайте репозиторий, коммитите каждую фичу**.
# - **Проект 2: Телефонная книга** — хранение в **SQLite**, импорт/экспорт в **JSON/CSV** → **.gitignore для .sqlite3 и .env**.
# - **Проект 3: Анализатор текста** — чтение из файла, статистика, сохранение отчёта → **коммиты с описанием: “Добавил подсчёт слов”, “Исправил кодировку”**.
# - **Проект 4: Дневник расходов** — категории, даты, сохранение в **SQLite**, экспорт в **CSV** → **push на GitHub после каждого этапа**.
# - **Проект 5: Менеджер задач (To-Do List)** — добавление, выполнение, удаление → **используйте .gitignore для игнорирования временных файлов**.
# - **Проект 6: Резервное копирование папки** — рекурсивный обход, архивация в **ZIP**, логирование → **создайте README.md с инструкцией по запуску**.
# - **Рефакторинг** — применение функций высшего порядка, лямбда, замыканий → **отдельная ветка? (подготовка к ООП-курсу)**.
# - **Защита проекта** — архитектура, выбор форматов, демонстрация, код-ревью → **ссылка на GitHub-репозиторий обязательна!**
#
#
#
# ## 📚 **Модуль 14: Дополнительные темы для развития**
# - Модуль `math` — математические функции
# - Модуль `random` — случайные числа, выбор, перемешивание
# - Модуль `datetime` — дата и время, форматирование
# - Модуль `sys` — аргументы командной строки (`sys.argv`)
# - Модуль `tempfile` — временные файлы
# - Рекурсия — углублённо (ограничения, хвостовая — введение)
# - Генераторы — `yield` (введение, сравнение с return)
# - Итераторы — протокол (`__iter__`, `__next__` — ознакомительно)
# - Основы тестирования: `doctest`, ручные тест-кейсы
# - **Продвинутый Git: ветвление, мерж, разрешение конфликтов (введение)**
# - Подготовка к следующему уровню: ООП, веб, данные, автоматизация
#
#
#
# ## ✅ **Заключение**
#
# Этот курс — **не просто "основы Python". Это фундамент реального разработчика.**
#
# Студенты научатся:
#
# 🔸 Писать чистый, структурированный, надёжный код
# 🔸 Работать с **любыми форматами данных** — от TXT до SQLite
# 🔸 Управлять **файлами и папками** — как в реальных проектах
# 🔸 Использовать **замыкания и лямбда** — для гибкости и краткости
# 🔸 Хранить данные в **SQLite** — профессионально и безопасно
# 🔸 Обрабатывать **ошибки** — чтобы программы не падали
# 🔸 **Работать с Git** — контроль версий с первого дня
# 🔸 Создавать **реальные проекты** — с сохранением, импортом, экспортом, логами
# 🔸 **Делиться кодом** через GitHub — готовить портфолио с самого начала

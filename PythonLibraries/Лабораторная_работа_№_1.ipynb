# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeHunterOfficial/ABC_DataMining/blob/main/PythonLibraries/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%E2%84%96_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 **Лабораторная работа № 1**
# ## *Подготовка учебных материалов и выполнение заданий по основам Python и ООП*
#
#
#
# ### 👨‍🏫 **Преподаватель:**
# **Арабов Муллошараф Курбюонович**
# *Старший преподаватель кафедры анализа данных и технологий программирования*
# *Казанский (Приволжский) федеральный университет (КФУ)*
#
# ### 📚 **Курс:**
# **«Python и его библиотеки»**
#
#
#
# ## 🎯 **Цель работы**
#
# Освоить базовые навыки работы со средой интерактивной разработки **Jupyter Notebook** через практическое преобразование текстовых фрагментов кода в исполняемые ячейки с сохранением структуры и логики изложения. Закрепить теоретические знания по **основам языка Python** и **объектно-ориентированному программированию (ООП)** путём выполнения индивидуального практического задания.
#
# > 💡 **Методическое примечание:**
# > *Для формирования целостного представления о переходе от базового синтаксиса Python к парадигме ООП, в рамках данной лабораторной работы объединены материалы двух начальных лекций:
# > — **[Lecture_1](https://github.com/CodeHunterOfficial/ABC_DataMining/tree/main/Python/Lecture_1) — «Основы языка Python»**
#
# > — **[Lecture_2](https://github.com/CodeHunterOfficial/ABC_DataMining/tree/main/Python/Lecture_2)— «Основы объектно-ориентированного программирования»**.*
#
# ## 📝 **Задание 1. Подготовка лекционных материалов к исполнению**
#
# Вам предоставлены два файла в формате Jupyter Notebook (`.ipynb`), содержащие материалы лекций. В текущем виде **все фрагменты кода встроены в текстовые ячейки (Markdown)** и не предназначены для выполнения.
#
# ### ✅ **Требования к выполнению:**
#
# 1. **Выделите все фрагменты кода** в каждом файле (`Lecture_1.ipynb`, `Lecture_2.ipynb`).
# 2. **Перенесите каждый фрагмент** в отдельную ячейку типа **Code**.
# 3. **Сохраните исходный текст** — не удаляйте и не изменяйте пояснения. Ячейки с кодом должны располагаться **непосредственно после соответствующих Markdown-пояснений**.
# 4. **Проверьте исполнение:**
#    Выполните последовательный запуск всех ячеек через команду:
#    `Kernel → Restart & Run All`
#    Убедитесь, что **ни одна ячейка не вызывает ошибок**.
#
#
#
# ### ⚠️ **Важные указания:**
#
# - Все текстовые пояснения **должны оставаться в ячейках типа Markdown**.
# - **Запрещается** произвольно удалять, сокращать или перемещать текст без необходимости.
# - Если вы обнаружили **ошибку в исходном коде лекции** — **исправьте её**, но **обязательно добавьте пояснение** в соседнюю Markdown-ячейку:
#   > **Примечание:** В строке 12 был исправлен синтаксис: `prnt()` → `print()`.
# - **Сообщите преподавателю** обо всех найденных неточностях — это ценится и поощряется!
#
#
#
# ## 🧩 **Задание 2. Индивидуальное практическое задание по ООП**
#
# После подготовки лекционных материалов выполните **индивидуальное задание**, соответствующее **вашему порядковому номеру в журнале успеваемости**.
#
# ### 📂 **Источник заданий:**
#
# 🔗 [**Практические_задания_по_ООП.ipynb**](https://github.com/CodeHunterOfficial/ABC_DataMining/blob/main/Python/Lecture_2/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B8%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D1%8F_%D0%BF%D0%BE_%D0%9E%D0%9E%D0%9F.ipynb)
#
# ### 💾 **Как правильно скачать файл:**
#
# 1. Перейдите по ссылке на GitHub.
# 2. Нажмите кнопку **`Raw`** (в правом верхнем углу файла).
# 3. В открывшейся «чистой» версии файла:
#    - Нажмите **ПКМ → «Сохранить как…»** (или `Ctrl+S` / `Cmd+S`).
#    - Убедитесь, что файл сохраняется с расширением **`.ipynb`**.
#    - Пример имени: `Практические_задания_по_ООП.ipynb`
#
#
#
# ## 📁 **Требования к оформлению и сдаче работы**
#
# ### 🗃️ **Формат отчёта:**
#
# Работа сдаётся в виде **ZIP-архива**, содержащего **три файла**:
#
# | № | Имя файла                     | Описание |
# |---|-------------------------------|----------|
# | 1 | `Lecture_1_prepared.ipynb`    | Подготовленный файл лекции 1 (все коды — в ячейках Code) |
# | 2 | `Lecture_2_prepared.ipynb`    | Подготовленный файл лекции 2 |
# | 3 | `ФАМИЛИЯ_ИО_LR1_OOP.ipynb`    | Решение вашего индивидуального задания *(например: `Арабов_МК_LR1_OOP.ipynb`)* |
#
# > 📌 **Имя архива:** `ФАМИЛИЯ_ИО_LR1.zip`
# > *(например: `Арабов_МК_LR1.zip`)*
#
#
#
# ## 📊 **Критерии оценки (максимум — 10 баллов)**
#
# ### 📌 **1. Подготовка лекционных материалов — до 5 баллов**
#
# | Критерий | Баллы |
# |----------|-------|
# | Все фрагменты кода перенесены в ячейки Code | +2 |
# | Сохранена структура и логика документа (текст → код) | +1 |
# | Все ячейки успешно выполняются без ошибок | +2 |
#
# ### 📌 **2. Решение практического задания — до 5 баллов**
#
# | Критерий | Баллы |
# |----------|-------|
# | Корректная реализация требуемой логики | +2 |
# | Соблюдение принципов ООП (инкапсуляция, наследование, полиморфизм) | +1 |
# | Чистота кода, соответствие PEP-8 (имена, отступы, структура) | +1 |
# | Наличие поясняющих комментариев (при необходимости) | +1 |
#
#
# ## ⏰ **Срок и место сдачи**
#
# > 📅 **Срок выполнения:** **2 недели** с момента получения задания.
# > 📍 **Место сдачи:** **Практическое занятие в ауд. 1103, КФУ**.
# > 🗓️ **Дата сдачи:** **Следующее практическое занятие** (проводится раз в неделю — уточняйте расписание).
#
# > ❗ **Важно:** Работа принимается **только в электронном виде** — на ноутбуке студента. Преподаватель проверит файлы на месте. Распечатки или скриншоты не принимаются.
#
#
# ## ❗ **Штрафные санкции:**
#
# - За **несвоевременную сдачу** (после начала практического занятия) — **минус 1 балл за каждые 24 часа просрочки**.
# - За **неправильное именование файлов или отсутствие ZIP-архива** — **минус 0.5 балла**.
# - За **отсутствие одного из файлов** — **минус 2 балла**.
#
#
#
# ✨ **Успехов в выполнении!**
# Эта работа — ваш первый шаг к уверенному владению Python и ООП. Подходите к ней внимательно — она закладывает фундамент для всех последующих лабораторных работ курса.
